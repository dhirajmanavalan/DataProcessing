# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.name = 'number'

# %%
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: number, dtype: int64

# %%
fruits = {
    'mango':20,
    'apple':10,
    'orange':200,
    'pine apple':30
}

# %%
s = pd.Series(fruits , name='proteins')

# %%
print(s)
# Out:
# mango          20
# apple          10
# orange        200
# pine apple     30
# Name: proteins, dtype: int64

# %%
s['orange'] = 10

# %%
print(s)
# Out:
# mango         20
# apple         10
# orange        10
# pine apple    30
# Name: proteins, dtype: int64

# %%
print(s.index)
# Out:
# Index(['mango', 'apple', 'orange', 'pine apple'], dtype='object')

# %%
# Dataframe
values = {
    'Names':["Dhiraj",'Dinesh','Monisha','Umadevi','Manavalan'],
    'Age':[23,23,29,47,52],
    'Gender':['Male','Male','Female','Female','Male']
}

# %%
data=pd.DataFrame(values)

# %%
print(data)
# Out:
#        Names  Age  Gender
# 0     Dhiraj   23    Male
# 1     Dinesh   23    Male
# 2    Monisha   29  Female
# 3    Umadevi   47  Female
# 4  Manavalan   52    Male

# %%
index = ['Me','Twin Brother','Elder Sister','Mother','Father']

# %%
data.index = index

# %%
print(data)
# Out:
#                   Names  Age  Gender
# Me               Dhiraj   23    Male
# Twin Brother     Dinesh   23    Male
# Elder Sister    Monisha   29  Female
# Mother          Umadevi   47  Female
# Father        Manavalan   52    Male

# %%
print(data.head(2))
# Out:
#                Names  Age Gender
# Me            Dhiraj   23   Male
# Twin Brother  Dinesh   23   Male

# %%
print(data.tail())
# Out:
#                   Names  Age  Gender
# Me               Dhiraj   23    Male
# Twin Brother     Dinesh   23    Male
# Elder Sister    Monisha   29  Female
# Mother          Umadevi   47  Female
# Father        Manavalan   52    Male

# %%
print(data.tail(2))
# Out:
#             Names  Age  Gender
# Mother    Umadevi   47  Female
# Father  Manavalan   52    Male

# %%
print(data.iloc[1:3])
# Out:
#                 Names  Age  Gender
# Twin Brother   Dinesh   23    Male
# Elder Sister  Monisha   29  Female

# %%
print(data.iloc[1:3])
# Out:
#                 Names  Age  Gender
# Twin Brother   Dinesh   23    Male
# Elder Sister  Monisha   29  Female

# %%
print(data.loc['Me':, ["Age"]])
# Out:
#               Age
# Me             23
# Twin Brother   23
# Elder Sister   29
# Mother         47
# Father         52

# %%
print(data.loc['Twin Brother':, ['Age']])
# Out:
#               Age
# Twin Brother   23
# Elder Sister   29
# Mother         47
# Father         52

# %%
data.iloc[1:3, 1:3]
# Out:
#               Age  Gender
# Twin Brother   23    Male
# Elder Sister   29  Female

# %%
data["Age"]
# Out:
# Me              23
# Twin Brother    23
# Elder Sister    29
# Mother          47
# Father          52
# Name: Age, dtype: int64

# %%
data[["Gender","Age"]]
# Out:
#               Gender  Age
# Me              Male   23
# Twin Brother    Male   23
# Elder Sister  Female   29
# Mother        Female   47
# Father          Male   52

# %%
data.drop("Age",axis=1)
# Out:
#                   Names  Gender
# Me               Dhiraj    Male
# Twin Brother     Dinesh    Male
# Elder Sister    Monisha  Female
# Mother          Umadevi  Female
# Father        Manavalan    Male

# %%
data.drop("Me",axis=0)
# Out:
#                   Names  Age  Gender
# Twin Brother     Dinesh   23    Male
# Elder Sister    Monisha   29  Female
# Mother          Umadevi   47  Female
# Father        Manavalan   52    Male

# %%
data
# Out:
#                   Names  Age  Gender
# Me               Dhiraj   23    Male
# Twin Brother     Dinesh   23    Male
# Elder Sister    Monisha   29  Female
# Mother          Umadevi   47  Female
# Father        Manavalan   52    Male

# %%
data.shape
# Out:
# (5, 3)

# %%
print(data.shape)
# Out:
# (5, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Me to Father
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Names   5 non-null      object
#  1   Age     5 non-null      int64
#  2   Gender  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 332.0+ bytes

# %%
data.describe()
# Out:
#              Age
# count   5.000000
# mean   34.800000
# std    13.754999
# min    23.000000
# 25%    23.000000
# 50%    29.000000
# 75%    47.000000
# max    52.000000

# %%
data
# Out:
#                   Names  Age  Gender
# Me               Dhiraj   23    Male
# Twin Brother     Dinesh   23    Male
# Elder Sister    Monisha   29  Female
# Mother          Umadevi   47  Female
# Father        Manavalan   52    Male

# %%
values = {
    'Names':["Dhiraj",'Dinesh','Monisha','Umadevi','Manavalan'],
    'Age':[23,23,29,47,52],
    'Gender':['Male','Male','Female','Female','Male'],
    'Salary':[2000,3000,4000,5000,6000]

}

# %%
data = pd.DataFrame(values)

# %%
data
# Out:
#        Names  Age  Gender  Salary
# 0     Dhiraj   23    Male    2000
# 1     Dinesh   23    Male    3000
# 2    Monisha   29  Female    4000
# 3    Umadevi   47  Female    5000
# 4  Manavalan   52    Male    6000

# %%
data.iloc[1:3, :2]
# Out:
#      Names  Age
# 1   Dinesh   23
# 2  Monisha   29

# %%
# Broadcasting
data["Salary"] = data["Salary"]+5000

# %%
data
# Out:
#        Names  Age  Gender  Salary
# 0     Dhiraj   23    Male    7000
# 1     Dinesh   23    Male    8000
# 2    Monisha   29  Female    9000
# 3    Umadevi   47  Female   10000
# 4  Manavalan   52    Male   11000

# %%
# Rename a column
data.rename(columns={'Age':'Ages'})
# Out:
#        Names  Ages  Gender  Salary
# 0     Dhiraj    23    Male    7000
# 1     Dinesh    23    Male    8000
# 2    Monisha    29  Female    9000
# 3    Umadevi    47  Female   10000
# 4  Manavalan    52    Male   11000

# %%
data
# Out:
#        Names  Age  Gender  Salary
# 0     Dhiraj   23    Male    7000
# 1     Dinesh   23    Male    8000
# 2    Monisha   29  Female    9000
# 3    Umadevi   47  Female   10000
# 4  Manavalan   52    Male   11000

# %%
data.rename(columns={'Age':'Ages'},inplace=True)

# %%
data
# Out:
#        Names  Ages  Gender  Salary
# 0     Dhiraj    23    Male    7000
# 1     Dinesh    23    Male    8000
# 2    Monisha    29  Female    9000
# 3    Umadevi    47  Female   10000
# 4  Manavalan    52    Male   11000

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      3
# Female    2
# Name: count, dtype: int64

# %%
data["Promoted Salary"] = data["Salary"]+2000

# %%
data
# Out:
#        Names  Ages  Gender  Salary  Promoted Salary
# 0     Dhiraj    23    Male    7000             9000
# 1     Dinesh    23    Male    8000            10000
# 2    Monisha    29  Female    9000            11000
# 3    Umadevi    47  Female   10000            12000
# 4  Manavalan    52    Male   11000            13000

# %%
data
# Out:
#        Names  Ages  Gender  Salary  Promoted Salary
# 0     Dhiraj    23    Male    7000             9000
# 1     Dinesh    23    Male    8000            10000
# 2    Monisha    29  Female    9000            11000
# 3    Umadevi    47  Female   10000            12000
# 4  Manavalan    52    Male   11000            13000

# %%
data['Work'] = ['Working','Studying','Lecturer','Teacher',"Civil Engineer"]

# %%
data
# Out:
#        Names  Ages  Gender  Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male    7000             9000         Working
# 1     Dinesh    23    Male    8000            10000        Studying
# 2    Monisha    29  Female    9000            11000        Lecturer
# 3    Umadevi    47  Female   10000            12000         Teacher
# 4  Manavalan    52    Male   11000            13000  Civil Engineer

# %%
data['Dhiraj'] = None

# %%
data
# Out:
#        Names  Ages  Gender  Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male    7000             9000         Working   None
# 1     Dinesh    23    Male    8000            10000        Studying   None
# 2    Monisha    29  Female    9000            11000        Lecturer   None
# 3    Umadevi    47  Female   10000            12000         Teacher   None
# 4  Manavalan    52    Male   11000            13000  Civil Engineer   None

# %%
data.loc[data['Names']=='Dhiraj','Salary']=None

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN             9000         Working   None
# 1     Dinesh    23    Male   8000.0            10000        Studying   None
# 2    Monisha    29  Female   9000.0            11000        Lecturer   None
# 3    Umadevi    47  Female  10000.0            12000         Teacher   None
# 4  Manavalan    52    Male  11000.0            13000  Civil Engineer   None

# %%
data['Promoted Salary'] = data['Salary']+2000

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN              NaN         Working   None
# 1     Dinesh    23    Male   8000.0          10000.0        Studying   None
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer   None
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher   None
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer   None

# %%
# Data Cleaning
data.isnull()
# Out:
#    Names   Ages  Gender  Salary  Promoted Salary   Work  Dhiraj
# 0  False  False   False    True             True  False    True
# 1  False  False   False   False            False  False    True
# 2  False  False   False   False            False  False    True
# 3  False  False   False   False            False  False    True
# 4  False  False   False   False            False  False    True

# %%
data.isnull().sum()
# Out:
# Names              0
# Ages               0
# Gender             0
# Salary             1
# Promoted Salary    1
# Work               0
# Dhiraj             5
# dtype: int64

# %%
print(data.dropna(how='all'))
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN              NaN         Working   None
# 1     Dinesh    23    Male   8000.0          10000.0        Studying   None
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer   None
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher   None
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer   None

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN              NaN         Working   None
# 1     Dinesh    23    Male   8000.0          10000.0        Studying   None
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer   None
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher   None
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer   None

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN              NaN         Working   None
# 1     Dinesh    23    Male   8000.0          10000.0        Studying   None
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer   None
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher   None
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer   None

# %%
data.drop('Dhiraj',axis=1)
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work Dhiraj
# 0     Dhiraj    23    Male      NaN              NaN         Working   None
# 1     Dinesh    23    Male   8000.0          10000.0        Studying   None
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer   None
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher   None
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer   None

# %%
data.drop('Dhiraj',axis=1,inplace=True)

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data.isnull()
# Out:
#    Names   Ages  Gender  Salary  Promoted Salary   Work
# 0  False  False   False    True             True  False
# 1  False  False   False   False            False  False
# 2  False  False   False   False            False  False
# 3  False  False   False   False            False  False
# 4  False  False   False   False            False  False

# %%
data.isnull().sum()
# Out:
# Names              0
# Ages               0
# Gender             0
# Salary             1
# Promoted Salary    1
# Work               0
# dtype: int64

# %%
data['Salary'].fillna(data['Salary'].mean())
# Out:
# 0     9500.0
# 1     8000.0
# 2     9000.0
# 3    10000.0
# 4    11000.0
# Name: Salary, dtype: float64

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data['Salary'].fillna(method='ffill')
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_11076\755933689.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Salary'].fillna(method='ffill')
# 0        NaN
# 1     8000.0
# 2     9000.0
# 3    10000.0
# 4    11000.0
# Name: Salary, dtype: float64

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data['Salary'].fillna(method = 'bfill')
# Out:
# C:\Users\dhira\AppData\Local\Temp\ipykernel_11076\327954280.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Salary'].fillna(method = 'bfill')
# 0     8000.0
# 1     8000.0
# 2     9000.0
# 3    10000.0
# 4    11000.0
# Name: Salary, dtype: float64

# %%
data['Names'].replace('Dhiraj','Dhi')
# Out:
# 0          Dhi
# 1       Dinesh
# 2      Monisha
# 3      Umadevi
# 4    Manavalan
# Name: Names, dtype: object

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0     Dhiraj    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data['Names'] = data['Names'].replace('Dhiraj','Dhiru')

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      DHiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data['Names'] = data['Names'].replace('Dhiraj','Dhiru')

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      DHiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data['Names'] = data['Names'].replace('DHiru','Dhiru')

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      Dhiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Names, Ages, Gender, Salary, Promoted Salary, Work]
# Index: []

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      Dhiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer

# %%
data = pd.concat([
    data,
    pd.DataFrame([{
        "Names": "Dinesh",
        "Ages": 23,
        "Gender": "Male",
        "Salary": 8000,
        "Promoted Salary": 10000,
        "Work": "Studying"
    }])
], ignore_index=True)

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      Dhiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer
# 5     Dinesh    23    Male   8000.0          10000.0        Studying

# %%
data[data.duplicated()]
# Out:
#     Names  Ages Gender  Salary  Promoted Salary      Work
# 5  Dinesh    23   Male  8000.0          10000.0  Studying

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      Dhiru    23    Male      NaN              NaN         Working
# 1     Dinesh    23    Male   8000.0          10000.0        Studying
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer
# 5     Dinesh    23    Male   8000.0          10000.0        Studying

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
data[data.duplicated()]
# Out:
#     Names  Ages Gender  Salary  Promoted Salary      Work
# 5  Dinesh    23   Male  8000.0          10000.0  Studying

# %%
data[data.duplicated(keep='first')]
# Out:
#     Names  Ages Gender  Salary  Promoted Salary      Work
# 5  Dinesh    23   Male  8000.0          10000.0  Studying

# %%
data[data.duplicated(keep='last')]
# Out:
#     Names  Ages Gender  Salary  Promoted Salary      Work
# 1  Dinesh    23   Male  8000.0          10000.0  Studying

# %%
data=data.drop_duplicates(keep='last')

# %%
data
# Out:
#        Names  Ages  Gender   Salary  Promoted Salary            Work
# 0      Dhiru    23    Male      NaN              NaN         Working
# 2    Monisha    29  Female   9000.0          11000.0        Lecturer
# 3    Umadevi    47  Female  10000.0          12000.0         Teacher
# 4  Manavalan    52    Male  11000.0          13000.0  Civil Engineer
# 5     Dinesh    23    Male   8000.0          10000.0        Studying

# %%
data = pd.read_csv("C:/Users/dhira/Downloads/Maven+Fuzzy+Factory\order_items.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\dhira\AppData\Local\Temp\ipykernel_11076\1939399627.py:1: SyntaxWarning: invalid escape sequence '\o'
#   data = pd.read_csv("C:/Users/dhira/Downloads/Maven+Fuzzy+Factory\order_items.csv")

# %%
data.head()
# Out:
#    order_item_id           created_at  order_id  product_id  is_primary_item  \
# 0              1  2012-03-19 10:42:46         1           1                1
# 1              2  2012-03-19 19:27:37         2           1                1
# 2              3  2012-03-20 06:44:45         3           1                1
# 3              4  2012-03-20 09:41:45         4           1                1
# 4              5  2012-03-20 11:28:15         5           1                1
#
#    price_usd  cogs_usd
# 0      49.99     19.49
# 1      49.99     19.49
# 2      49.99     19.49
# 3      49.99     19.49
# 4      49.99     19.49

# %%
data.head(7)
# Out:
#    order_item_id           created_at  order_id  product_id  is_primary_item  \
# 0              1  2012-03-19 10:42:46         1           1                1
# 1              2  2012-03-19 19:27:37         2           1                1
# 2              3  2012-03-20 06:44:45         3           1                1
# 3              4  2012-03-20 09:41:45         4           1                1
# 4              5  2012-03-20 11:28:15         5           1                1
# 5              6  2012-03-20 16:12:47         6           1                1
# 6              7  2012-03-20 17:03:41         7           1                1
#
#    price_usd  cogs_usd
# 0      49.99     19.49
# 1      49.99     19.49
# 2      49.99     19.49
# 3      49.99     19.49
# 4      49.99     19.49
# 5      49.99     19.49
# 6      49.99     19.49

# %%
data.shape
# Out:
# (40025, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40025 entries, 0 to 40024
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_item_id    40025 non-null  int64
#  1   created_at       40025 non-null  object
#  2   order_id         40025 non-null  int64
#  3   product_id       40025 non-null  int64
#  4   is_primary_item  40025 non-null  int64
#  5   price_usd        40025 non-null  float64
#  6   cogs_usd         40025 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 2.1+ MB
