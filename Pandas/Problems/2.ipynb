# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40])

# %%
a=s.tolist()

# %%
print("List",a)
print("pandas",s)
# Out:
# List [10, 20, 30, 40]
# pandas 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
